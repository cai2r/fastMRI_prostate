# %% [markdown]
# ### ====== Loading, Reconstructing and Visualizing the fastMRI Prostate dataset ======
#
# #### To download the fastMRI prostate dataset: https://fastmri.med.nyu.edu/

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/gpfs/scratch/jhad02/Tasks/Task001-GrappaGPU/fastMRI_prostate/')

# %%
import argparse
import h5py
import numpy as np
from pathlib import Path
from matplotlib import pyplot as plt
import xml.etree.ElementTree as etree
from fastmri_prostate.reconstruction.t2.prostate_t2_recon_torch import t2_reconstruction
from fastmri_prostate.reconstruction.dwi.prostate_dwi_recon_torch import dwi_reconstruction
from fastmri_prostate.data.mri_data import load_file_T2, load_file_dwi, save_recon
import warnings
import os
warnings.filterwarnings('ignore')

import torch

# %%
#! Below: Add full folder path to downloaded fastMRI prostate data
fastMRI_dir = "/gpfs/scratch/jhad02/Tasks/data/prostate"

data_path_t2 = 'fastMRI_prostate_T2_IDS_001_020'
data_path_dwi = 'fastMRI_prostate_DIFF_IDS_001_011'

# %% [markdown]
# The fastMRI Prostate dataset is distributed as a set of HDF5 files that can be read with the h5py package

# %%
fname_t2 = os.path.join(fastMRI_dir, data_path_t2, 'file_prostate_AXT2_001.h5')
fname_dwi = os.path.join(fastMRI_dir,data_path_dwi, 'file_prostate_AXDIFF_001.h5')

# %% [markdown]
# ## ---------------------------- T2  ----------------------------

# %% [markdown]
# ### Example - how to load, reconstruct and visualize the T2 data. Data dimensions are explained here as well.

# %%
kspace, calibration_data, ismrmrd_header, reconstruction_rss, image_atts = load_file_T2(fname_t2)

print("Sizes of the array fields in the fastMRI prostate T2 file:")
print("kspace:", kspace.shape, ", calibration_data:", calibration_data.shape, ", reconstruction_rss:", reconstruction_rss.shape)
# Out:
# Sizes of the array fields in the fastMRI prostate T2 file:
# kspace: (3, 30, 20, 640, 451) , calibration_data: (30, 20, 640, 32) , reconstruction_rss: (30, 320, 320)

# %% [markdown]
# Description of fields in the fastMRI prostate T2 file:
#
# - "ismrmrd_header" => ISMRMRD header => scan acquisition parameters (https://ismrmrd.github.io/apidocs/1.5.0/)
# - "kspace" => T2 raw k-space with dimensions => averages, slices, coils, readout, phase
# - "reconstruction_rss" => Reconstructed T2 image volume with dimensions => slices, x, y
# - "calibration_data" => Calibration scan acquired with dimensions => slices, coils, readout, phase

# %% [markdown]
# #### T2 reconstruction takes as input the kspace, calibration data and the ISMRMRD header => to outputs a dictionary containing the reconstructed image

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# ismrmrd_header = {k: torch.tensor(v, device=device) for k, v in ismrmrd_header.items()}
kspace = torch.tensor(kspace, device=device)
calibration_data = torch.tensor(calibration_data, device=device)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 7
#       4     device = torch.device("cpu")
#       6 # breakpoint()
# ----> 7 ismrmrd_header = {k: torch.tensor(v, device=device) for k, v in ismrmrd_header.items()}
#       8 kspace = torch.tensor(kspace, device=device)
#       9 calibration_data = torch.tensor(calibration_data, device=device)
#
# AttributeError: 'bytes' object has no attribute 'items'

# %%
# %%time
img_dict_t2 = t2_reconstruction(kspace, calibration_data, ismrmrd_header)
print("Size of reconstructed data:")
print(img_dict_t2['reconstruction_rss'].shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:1
#
# File /gpfs/scratch/jhad02/Tasks/Task001-GrappaGPU/fastMRI_prostate/fastmri_prostate/reconstruction/t2/prostate_t2_recon_torch.py:78, in t2_reconstruction(kspace_data, calib_data, hdr)
#      75 grappa_weight_dict_2 = {}
#      77 kspace_slice_regridded = kspace_data[0, 0, ...]
# ---> 78 grappa_obj = Grappa(kspace_slice_regridded.permute(2, 0, 1), kernel_size=(5, 5), coil_axis=1)
#      80 kspace_slice_regridded_2 = kspace_data[1, 0, ...]
#      81 grappa_obj_2 = Grappa(kspace_slice_regridded_2.permute(2, 0, 1), kernel_size=(5, 5), coil_axis=1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'permute'

# %% [markdown]
# ### Plotting the reconstructed T2 image, which is the same as 'reconstruction_rss' present in the h5 file

# %%
def display_t2_slice(img, slice_num):
    plt.imshow(img[slice_num, :, :] , cmap='gray')
    plt.title("Reconstructed T2 image - slice 11")
    plt.axis("off")
display_t2_slice(img_dict_t2['reconstruction_rss'], 10)

# %% [markdown]
# ## ---------------------------- DWI  ----------------------------

# %% [markdown]
# ### Example - how to load, reconstruct and visualize the DWI data. Data dimensions are explained here as well.

# %%
kspace, calibration_data, coil_sens_maps, ismrmrd_header = load_file_dwi(fname_dwi)

print("Sizes of the array fields in the fastMRI prostate DWI file:")
print("kspace:", kspace.shape, ", calibration_data:", calibration_data.shape, ", coil_sens_maps:", coil_sens_maps.shape)
# Out:
# Sizes of the array fields in the fastMRI prostate DWI file:
# kspace: (50, 30, 20, 200, 150) , calibration_data: (30, 20, 200, 32) , coil_sens_maps: (30, 20, 200, 150)

# %% [markdown]
# Description of fields in the fastMRI prostate DWI file:
#
# - "ismrmrd_header" => ISMRMRD header => scan acquisition parameters (https://ismrmrd.github.io/apidocs/1.5.0/)
# - "kspace" => T2 raw k-space with dimensions => diffusion*, slices, coils, readout, phase
# - "calibration_data" => Calibration scan acquired with dimensions => slices, coils, readout, phase
# - "coil_sens_maps" => Coil sensitivity maps calculated using ESPIRIT with dimensions  => slices, coils, readout, phase
#
# *diffusion dimension is comprised of multiple averages for different B strengths, they can be parsed out in the following way:
#
# - B0_avg1   => kspace[0,:]
# - B0_avg2   => kspace[1,:]
# - B50x_avg1 => kspace[2,:]
# - B50x_avg2 => kspace[8,:]
# - B50x_avg3 => kspace[14,:]
# - B50x_avg4 => kspace[20,:]
# - B50y_avg1 => kspace[3,:]
# - B50y_avg2 => kspace[9,:]
# - B50y_avg3 => kspace[15,:]
# - B50y_avg4 => kspace[21,:]
# - B50z_avg1 => kspace[4,:]
# - B50z_avg2 => kspace[10,:]
# - B50z_avg3 => kspace[16,:]
# - B50z_avg4 => kspace[22,:]
# - B1000x_avg1 => kspace[5,:]
# - B1000x_avg2 => kspace[11,:]
# - B1000x_avg3 => kspace[17,:]
# - B1000x_avg4 => kspace[23,:]
# - B1000x_avg5 => kspace[26,:]
# - B1000x_avg6 => kspace[29,:]
# - B1000x_avg7 => kspace[32,:]
# - B1000x_avg8 => kspace[35,:]
# - B1000x_avg9 => kspace[38,:]
# - B1000x_avg10 => kspace[41,:]
# - B1000x_avg11 => kspace[44,:]
# - B1000x_avg12 => kspace[47,:]
# - B1000y_avg1 => kspace[6,:]
# - B1000y_avg2 => kspace[12,:]
# - B1000y_avg3 => kspace[18,:]
# - B1000y_avg4 => kspace[24,:]
# - B1000y_avg5 => kspace[27,:]
# - B1000y_avg6 => kspace[30,:]
# - B1000y_avg7 => kspace[33,:]
# - B1000y_avg8 => kspace[36,:]
# - B1000y_avg9 => kspace[39,:]
# - B1000y_avg10 => kspace[42,:]
# - B1000y_avg11 => kspace[45,:]
# - B1000y_avg12 => kspace[48,:]
# - B1000z_avg1 => kspace[7,:]
# - B1000z_avg2 => kspace[13,:]
# - B1000z_avg3 => kspace[19,:]
# - B1000z_avg4 => kspace[25,:]
# - B1000z_avg5 => kspace[28,:]
# - B1000z_avg6 => kspace[31,:]
# - B1000z_avg7 => kspace[34,:]
# - B1000z_avg8 => kspace[37,:]
# - B1000z_avg9 => kspace[40,:]
# - B1000z_avg10 => kspace[43,:]
# - B1000z_avg11 => kspace[46,:]
# - B1000z_avg12 => kspace[49,:]

# %% [markdown]
# #### DWI reconstruction takes as input the kspace, calibration data, coil sensitivity maps and the ISMRMRD header => to outputs a dictionary containing the reconstructed images

# %%
# %%time
img_dict_dwi = dwi_reconstruction(kspace, calibration_data, coil_sens_maps, ismrmrd_header)
print("Size of B50x image (as an example):")
print(img_dict_dwi['b50x'].shape)
print("Size of ADC map (as an example):")
print(img_dict_dwi['adc_map'].shape)
# Out:
# time taken to compute weights for slice 0: 0.1292264461517334
# time taken to compute weights for slice 1: 0.10793328285217285
# time taken to compute weights for slice 2: 0.10974574089050293
# time taken to compute weights for slice 3: 0.11562085151672363
# time taken to compute weights for slice 4: 0.10902714729309082
# time taken to compute weights for slice 5: 0.11730647087097168
# time taken to compute weights for slice 6: 0.11933112144470215
# time taken to compute weights for slice 7: 0.115570068359375
# time taken to compute weights for slice 8: 0.1216886043548584
# time taken to compute weights for slice 9: 0.11714911460876465
# time taken to compute weights for slice 10: 0.1176910400390625
# time taken to compute weights for slice 11: 0.11628174781799316
# time taken to compute weights for slice 12: 0.11793255805969238
# time taken to compute weights for slice 13: 0.10818052291870117
# time taken to compute weights for slice 14: 0.12040281295776367
# time taken to compute weights for slice 15: 0.11824536323547363
# time taken to compute weights for slice 16: 0.11749076843261719
# time taken to compute weights for slice 17: 0.12034916877746582
# time taken to compute weights for slice 18: 0.11851119995117188
# time taken to compute weights for slice 19: 0.11955666542053223
# time taken to compute weights for slice 20: 0.11700987815856934
# time taken to compute weights for slice 21: 0.1130061149597168
# time taken to compute weights for slice 22: 0.1134943962097168
# time taken to compute weights for slice 23: 0.11157011985778809
# time taken to compute weights for slice 24: 0.11202621459960938
# time taken to compute weights for slice 25: 0.11008572578430176
# time taken to compute weights for slice 26: 0.11298370361328125
# time taken to compute weights for slice 27: 0.11109781265258789
# time taken to compute weights for slice 28: 0.11226940155029297
# time taken to compute weights for slice 29: 0.10980033874511719
# ######################### time taken to apply weights: 0.0013687610626220703
# ######################### time taken to apply weights: 5.125999450683594e-05
# ######################### time taken to apply weights: 0.0002377033233642578
# ######################### time taken to apply weights: 3.409385681152344e-05
# ######################### time taken to apply weights: 0.0027191638946533203
# ######################### time taken to apply weights: 0.001520395278930664
# ######################### time taken to apply weights: 0.0010933876037597656
# ######################### time taken to apply weights: 0.0013740062713623047
# ######################### time taken to apply weights: 0.0010805130004882812
# ######################### time taken to apply weights: 0.17008423805236816
# ######################### FULL time taken to apply weights: 0.18024778366088867
# ######################### time taken to apply weights: 0.0012631416320800781
# ######################### time taken to apply weights: 4.76837158203125e-05
# ######################### time taken to apply weights: 0.00021886825561523438
# ######################### time taken to apply weights: 3.600120544433594e-05
# ######################### time taken to apply weights: 0.0029175281524658203
# ######################### time taken to apply weights: 0.0016145706176757812
# ######################### time taken to apply weights: 0.0012094974517822266
# ######################### time taken to apply weights: 0.0013778209686279297
# ######################### time taken to apply weights: 0.001313924789428711
# ######################### time taken to apply weights: 0.1692032814025879
# ######################### FULL time taken to apply weights: 0.17992353439331055
# ######################### time taken to apply weights: 0.0011820793151855469
# ######################### time taken to apply weights: 4.553794860839844e-05
# ######################### time taken to apply weights: 0.00020194053649902344
# ######################### time taken to apply weights: 3.3855438232421875e-05
# ######################### time taken to apply weights: 0.0028841495513916016
# ######################### time taken to apply weights: 0.0015692710876464844
# ######################### time taken to apply weights: 0.0010902881622314453
# ######################### time taken to apply weights: 0.0013496875762939453
# ######################### time taken to apply weights: 0.0013213157653808594
# ######################### time taken to apply weights: 0.16554522514343262
# ######################### FULL time taken to apply weights: 0.17599821090698242
# ######################### time taken to apply weights: 0.0011515617370605469
# ######################### time taken to apply weights: 4.839897155761719e-05
# ######################### time taken to apply weights: 0.00020432472229003906
# ######################### time taken to apply weights: 3.5762786865234375e-05
# ######################### time taken to apply weights: 0.002943754196166992
# ######################### time taken to apply weights: 0.0015635490417480469
# ######################### time taken to apply weights: 0.0011801719665527344
# ######################### time taken to apply weights: 0.0013549327850341797
# ######################### time taken to apply weights: 0.0013091564178466797
# ######################### time taken to apply weights: 0.16508126258850098
# ######################### FULL time taken to apply weights: 0.17554163932800293
# ######################### time taken to apply weights: 0.0011820793151855469
# ######################### time taken to apply weights: 4.673004150390625e-05
# ######################### time taken to apply weights: 0.0002582073211669922
# ######################### time taken to apply weights: 3.7670135498046875e-05
# ######################### time taken to apply weights: 0.0029296875
# ######################### time taken to apply weights: 0.00156402587890625
# ######################### time taken to apply weights: 0.0011906623840332031
# ######################### time taken to apply weights: 0.0014255046844482422
# ######################### time taken to apply weights: 0.001308441162109375
# ######################### time taken to apply weights: 0.16452932357788086
# ######################### FULL time taken to apply weights: 0.17526531219482422
# ######################### time taken to apply weights: 0.0011467933654785156
# ######################### time taken to apply weights: 4.601478576660156e-05
# ######################### time taken to apply weights: 3.0517578125e-05
# ######################### time taken to apply weights: 2.3603439331054688e-05
# ######################### time taken to apply weights: 0.003398418426513672
# ######################### time taken to apply weights: 0.0015821456909179688
# ######################### time taken to apply weights: 0.0011792182922363281
# ######################### time taken to apply weights: 0.0013663768768310547
# ######################### time taken to apply weights: 0.0013108253479003906
# ######################### time taken to apply weights: 0.16529488563537598
# ######################### FULL time taken to apply weights: 0.17611360549926758
# ######################### time taken to apply weights: 0.0011370182037353516
# ######################### time taken to apply weights: 4.601478576660156e-05
# ######################### time taken to apply weights: 0.0002741813659667969
# ######################### time taken to apply weights: 4.291534423828125e-05
# ######################### time taken to apply weights: 0.0031752586364746094
# ######################### time taken to apply weights: 0.0019769668579101562
# ######################### time taken to apply weights: 0.0012235641479492188
# ######################### time taken to apply weights: 0.0013539791107177734
# ######################### time taken to apply weights: 0.0013093948364257812
# ######################### time taken to apply weights: 0.16798615455627441
# ######################### FULL time taken to apply weights: 0.17939233779907227
# ######################### time taken to apply weights: 0.0011632442474365234
# ######################### time taken to apply weights: 5.602836608886719e-05
# ######################### time taken to apply weights: 3.933906555175781e-05
# ######################### time taken to apply weights: 3.218650817871094e-05
# ######################### time taken to apply weights: 0.0036110877990722656
# ######################### time taken to apply weights: 0.0015892982482910156
# ######################### time taken to apply weights: 0.0012025833129882812
# ######################### time taken to apply weights: 0.0013759136199951172
# ######################### time taken to apply weights: 0.001317739486694336
# ######################### time taken to apply weights: 0.16543006896972656
# ######################### FULL time taken to apply weights: 0.1764991283416748
# ######################### time taken to apply weights: 0.0011749267578125
# ######################### time taken to apply weights: 5.054473876953125e-05
# ######################### time taken to apply weights: 3.409385681152344e-05
# ######################### time taken to apply weights: 2.86102294921875e-05
# ######################### time taken to apply weights: 0.003492593765258789
# ######################### time taken to apply weights: 0.0016491413116455078
# ######################### time taken to apply weights: 0.001100778579711914
# ######################### time taken to apply weights: 0.0013468265533447266
# ######################### time taken to apply weights: 0.0013089179992675781
# ######################### time taken to apply weights: 0.1656174659729004
# ######################### FULL time taken to apply weights: 0.17656660079956055
# ######################### time taken to apply weights: 0.0011806488037109375
# ######################### time taken to apply weights: 5.173683166503906e-05
# ######################### time taken to apply weights: 0.0002803802490234375
# ######################### time taken to apply weights: 4.3392181396484375e-05
# ######################### time taken to apply weights: 0.0034012794494628906
# ######################### time taken to apply weights: 0.0017101764678955078
# ######################### time taken to apply weights: 0.001192331314086914
# ######################### time taken to apply weights: 0.0013751983642578125
# ######################### time taken to apply weights: 0.0013141632080078125
# ######################### time taken to apply weights: 0.16632747650146484
# ######################### FULL time taken to apply weights: 0.1776425838470459
# ######################### time taken to apply weights: 0.0011584758758544922
# ######################### time taken to apply weights: 5.2928924560546875e-05
# ######################### time taken to apply weights: 3.409385681152344e-05
# ######################### time taken to apply weights: 2.6226043701171875e-05
# ######################### time taken to apply weights: 0.003420591354370117
# ######################### time taken to apply weights: 0.0015833377838134766
# ######################### time taken to apply weights: 0.0011894702911376953
# ######################### time taken to apply weights: 0.0013499259948730469
# ######################### time taken to apply weights: 0.0013201236724853516
# ######################### time taken to apply weights: 0.16799354553222656
# ######################### FULL time taken to apply weights: 0.17888736724853516
# ######################### time taken to apply weights: 0.0013163089752197266
# ######################### time taken to apply weights: 6.246566772460938e-05
# ######################### time taken to apply weights: 0.0003046989440917969
# ######################### time taken to apply weights: 4.410743713378906e-05
# ######################### time taken to apply weights: 0.003011941909790039
# ######################### time taken to apply weights: 0.0015728473663330078
# ######################### time taken to apply weights: 0.001207113265991211
# ######################### time taken to apply weights: 0.0013549327850341797
# ######################### time taken to apply weights: 0.0013041496276855469
# ######################### time taken to apply weights: 0.1680305004119873
# ######################### FULL time taken to apply weights: 0.17901301383972168
# ######################### time taken to apply weights: 0.0013163089752197266
# ######################### time taken to apply weights: 6.270408630371094e-05
# ######################### time taken to apply weights: 9.703636169433594e-05
# ######################### time taken to apply weights: 4.029273986816406e-05
# ######################### time taken to apply weights: 0.003058195114135742
# ######################### time taken to apply weights: 0.0015757083892822266
# ######################### time taken to apply weights: 0.0011744499206542969
# ######################### time taken to apply weights: 0.0013763904571533203
# ######################### time taken to apply weights: 0.0013070106506347656
# ######################### time taken to apply weights: 0.1673717498779297
# ######################### FULL time taken to apply weights: 0.17832231521606445
# ######################### time taken to apply weights: 0.001394033432006836
# ######################### time taken to apply weights: 6.365776062011719e-05
# ######################### time taken to apply weights: 0.00025010108947753906
# ######################### time taken to apply weights: 4.076957702636719e-05
# ######################### time taken to apply weights: 0.0030128955841064453
# ######################### time taken to apply weights: 0.0015704631805419922
# ######################### time taken to apply weights: 0.0011768341064453125
# ######################### time taken to apply weights: 0.001348733901977539
# ######################### time taken to apply weights: 0.0013577938079833984
# ######################### time taken to apply weights: 0.16569900512695312
# ######################### FULL time taken to apply weights: 0.1766068935394287
# ######################### time taken to apply weights: 0.001428842544555664
# ######################### time taken to apply weights: 6.341934204101562e-05
# ######################### time taken to apply weights: 0.00025916099548339844
# ######################### time taken to apply weights: 3.814697265625e-05
# ######################### time taken to apply weights: 0.0030069351196289062
# ######################### time taken to apply weights: 0.001569509506225586
# ######################### time taken to apply weights: 0.0011742115020751953
# ######################### time taken to apply weights: 0.0013661384582519531
# ######################### time taken to apply weights: 0.0013117790222167969
# ######################### time taken to apply weights: 0.1669318675994873
# ######################### FULL time taken to apply weights: 0.17794370651245117
# ######################### time taken to apply weights: 0.0013968944549560547
# ######################### time taken to apply weights: 6.699562072753906e-05
# ######################### time taken to apply weights: 0.0002720355987548828
# ######################### time taken to apply weights: 4.00543212890625e-05
# ######################### time taken to apply weights: 0.0029382705688476562
# ######################### time taken to apply weights: 0.0015959739685058594
# ######################### time taken to apply weights: 0.0011889934539794922
# ######################### time taken to apply weights: 0.0013599395751953125
# ######################### time taken to apply weights: 0.0013129711151123047
# ######################### time taken to apply weights: 0.16617441177368164
# ######################### FULL time taken to apply weights: 0.17724251747131348
# ######################### time taken to apply weights: 0.0011947154998779297
# ######################### time taken to apply weights: 6.318092346191406e-05
# ######################### time taken to apply weights: 0.0002617835998535156
# ######################### time taken to apply weights: 4.38690185546875e-05
# ######################### time taken to apply weights: 0.003035306930541992
# ######################### time taken to apply weights: 0.0015745162963867188
# ######################### time taken to apply weights: 0.0011780261993408203
# ######################### time taken to apply weights: 0.0013642311096191406
# ######################### time taken to apply weights: 0.0013141632080078125
# ######################### time taken to apply weights: 0.16828107833862305
# ######################### FULL time taken to apply weights: 0.1790766716003418
# ######################### time taken to apply weights: 0.0012848377227783203
# ######################### time taken to apply weights: 6.0558319091796875e-05
# ######################### time taken to apply weights: 0.0002639293670654297
# ######################### time taken to apply weights: 4.291534423828125e-05
# ######################### time taken to apply weights: 0.0030405521392822266
# ######################### time taken to apply weights: 0.0015616416931152344
# ######################### time taken to apply weights: 0.0011746883392333984
# ######################### time taken to apply weights: 0.0013720989227294922
# ######################### time taken to apply weights: 0.0013265609741210938
# ######################### time taken to apply weights: 0.16790461540222168
# ######################### FULL time taken to apply weights: 0.17876243591308594
# ######################### time taken to apply weights: 0.001444101333618164
# ######################### time taken to apply weights: 6.651878356933594e-05
# ######################### time taken to apply weights: 0.0002777576446533203
# ######################### time taken to apply weights: 4.506111145019531e-05
# ######################### time taken to apply weights: 0.002992391586303711
# ######################### time taken to apply weights: 0.0015766620635986328
# ######################### time taken to apply weights: 0.0011856555938720703
# ######################### time taken to apply weights: 0.0013709068298339844
# ######################### time taken to apply weights: 0.0013120174407958984
# ######################### time taken to apply weights: 0.16724681854248047
# ######################### FULL time taken to apply weights: 0.17824339866638184
# ######################### time taken to apply weights: 0.001186370849609375
# ######################### time taken to apply weights: 4.76837158203125e-05
# ######################### time taken to apply weights: 0.00023245811462402344
# ######################### time taken to apply weights: 3.528594970703125e-05
# ######################### time taken to apply weights: 0.002925395965576172
# ######################### time taken to apply weights: 0.0015807151794433594
# ######################### time taken to apply weights: 0.0010950565338134766
# ######################### time taken to apply weights: 0.0012569427490234375
# ######################### time taken to apply weights: 0.0010554790496826172
# ######################### time taken to apply weights: 0.1666853427886963
# ######################### FULL time taken to apply weights: 0.17674732208251953
# ######################### time taken to apply weights: 0.0012226104736328125
# ######################### time taken to apply weights: 6.246566772460938e-05
# ######################### time taken to apply weights: 0.0002777576446533203
# ######################### time taken to apply weights: 4.315376281738281e-05
# ######################### time taken to apply weights: 0.002992868423461914
# ######################### time taken to apply weights: 0.0015702247619628906
# ######################### time taken to apply weights: 0.0012001991271972656
# ######################### time taken to apply weights: 0.0013561248779296875
# ######################### time taken to apply weights: 0.0013113021850585938
# ######################### time taken to apply weights: 0.1677837371826172
# ######################### FULL time taken to apply weights: 0.17862749099731445
# ######################### time taken to apply weights: 0.0014102458953857422
# ######################### time taken to apply weights: 6.914138793945312e-05
# ######################### time taken to apply weights: 0.0002532005310058594
# ######################### time taken to apply weights: 4.076957702636719e-05
# ######################### time taken to apply weights: 0.0029785633087158203
# ######################### time taken to apply weights: 0.001569509506225586
# ######################### time taken to apply weights: 0.0012021064758300781
# ######################### time taken to apply weights: 0.0013034343719482422
# ######################### time taken to apply weights: 0.001313924789428711
# ######################### time taken to apply weights: 0.16928339004516602
# ######################### FULL time taken to apply weights: 0.1802220344543457
# ######################### time taken to apply weights: 0.0011715888977050781
# ######################### time taken to apply weights: 6.508827209472656e-05
# ######################### time taken to apply weights: 0.00027751922607421875
# ######################### time taken to apply weights: 4.6253204345703125e-05
# ######################### time taken to apply weights: 0.003115415573120117
# ######################### time taken to apply weights: 0.001569509506225586
# ######################### time taken to apply weights: 0.0011761188507080078
# ######################### time taken to apply weights: 0.0013682842254638672
# ######################### time taken to apply weights: 0.001321554183959961
# ######################### time taken to apply weights: 0.16727876663208008
# ######################### FULL time taken to apply weights: 0.17808914184570312
# ######################### time taken to apply weights: 0.0012249946594238281
# ######################### time taken to apply weights: 6.29425048828125e-05
# ######################### time taken to apply weights: 0.00026226043701171875
# ######################### time taken to apply weights: 4.3392181396484375e-05
# ######################### time taken to apply weights: 0.003058910369873047
# ######################### time taken to apply weights: 0.0015594959259033203
# ######################### time taken to apply weights: 0.0011794567108154297
# ######################### time taken to apply weights: 0.0013523101806640625
# ######################### time taken to apply weights: 0.0013175010681152344
# ######################### time taken to apply weights: 0.1674811840057373
# ######################### FULL time taken to apply weights: 0.17814016342163086
# ######################### time taken to apply weights: 0.0013968944549560547
# ######################### time taken to apply weights: 7.462501525878906e-05
# ######################### time taken to apply weights: 0.0002644062042236328
# ######################### time taken to apply weights: 4.124641418457031e-05
# ######################### time taken to apply weights: 0.0029904842376708984
# ######################### time taken to apply weights: 0.0015795230865478516
# ######################### time taken to apply weights: 0.0011758804321289062
# ######################### time taken to apply weights: 0.00136566162109375
# ######################### time taken to apply weights: 0.0013020038604736328
# ######################### time taken to apply weights: 0.16686105728149414
# ######################### FULL time taken to apply weights: 0.17777800559997559
# ######################### time taken to apply weights: 0.0013554096221923828
# ######################### time taken to apply weights: 7.82012939453125e-05
# ######################### time taken to apply weights: 0.0002570152282714844
# ######################### time taken to apply weights: 4.100799560546875e-05
# ######################### time taken to apply weights: 0.0029866695404052734
# ######################### time taken to apply weights: 0.0015692710876464844
# ######################### time taken to apply weights: 0.0011904239654541016
# ######################### time taken to apply weights: 0.0013661384582519531
# ######################### time taken to apply weights: 0.0013194084167480469
# ######################### time taken to apply weights: 0.1653156280517578
# ######################### FULL time taken to apply weights: 0.17622613906860352
# ######################### time taken to apply weights: 0.0011181831359863281
# ######################### time taken to apply weights: 5.078315734863281e-05
# ######################### time taken to apply weights: 3.218650817871094e-05
# ######################### time taken to apply weights: 2.765655517578125e-05
# ######################### time taken to apply weights: 0.0033600330352783203
# ######################### time taken to apply weights: 0.0015683174133300781
# ######################### time taken to apply weights: 0.0012080669403076172
# ######################### time taken to apply weights: 0.0013644695281982422
# ######################### time taken to apply weights: 0.0013015270233154297
# ######################### time taken to apply weights: 0.16856908798217773
# ######################### FULL time taken to apply weights: 0.1793816089630127
# ######################### time taken to apply weights: 0.0014057159423828125
# ######################### time taken to apply weights: 6.4849853515625e-05
# ######################### time taken to apply weights: 0.0002601146697998047
# ######################### time taken to apply weights: 4.076957702636719e-05
# ######################### time taken to apply weights: 0.0030677318572998047
# ######################### time taken to apply weights: 0.0015668869018554688
# ######################### time taken to apply weights: 0.001184225082397461
# ######################### time taken to apply weights: 0.0013582706451416016
# ######################### time taken to apply weights: 0.001298666000366211
# ######################### time taken to apply weights: 0.1662311553955078
# ######################### FULL time taken to apply weights: 0.17730236053466797
# ######################### time taken to apply weights: 0.0013501644134521484
# ######################### time taken to apply weights: 6.461143493652344e-05
# ######################### time taken to apply weights: 0.0002663135528564453
# ######################### time taken to apply weights: 4.3392181396484375e-05
# ######################### time taken to apply weights: 0.003015279769897461
# ######################### time taken to apply weights: 0.0015592575073242188
# ######################### time taken to apply weights: 0.0011818408966064453
# ######################### time taken to apply weights: 0.0013527870178222656
# ######################### time taken to apply weights: 0.0013151168823242188
# ######################### time taken to apply weights: 0.167496919631958
# ######################### FULL time taken to apply weights: 0.17845630645751953
# ######################### time taken to apply weights: 0.0012493133544921875
# ######################### time taken to apply weights: 6.4849853515625e-05
# ######################### time taken to apply weights: 0.0002727508544921875
# ######################### time taken to apply weights: 4.38690185546875e-05
# ######################### time taken to apply weights: 0.0030863285064697266
# ######################### time taken to apply weights: 0.0015594959259033203
# ######################### time taken to apply weights: 0.0011844635009765625
# ######################### time taken to apply weights: 0.0013539791107177734
# ######################### time taken to apply weights: 0.0013275146484375
# ######################### time taken to apply weights: 0.16582393646240234
# ######################### FULL time taken to apply weights: 0.17667841911315918
# ######################### time taken to apply weights: 0.0012135505676269531
# ######################### time taken to apply weights: 6.318092346191406e-05
# ######################### time taken to apply weights: 0.0002601146697998047
# ######################### time taken to apply weights: 4.1484832763671875e-05
# ######################### time taken to apply weights: 0.0030727386474609375
# ######################### time taken to apply weights: 0.001566171646118164
# ######################### time taken to apply weights: 0.0012080669403076172
# ######################### time taken to apply weights: 0.0013964176177978516
# ######################### time taken to apply weights: 0.0013163089752197266
# ######################### time taken to apply weights: 0.16764259338378906
# ######################### FULL time taken to apply weights: 0.17852234840393066
# ######################### time taken to apply weights: 0.0013210773468017578
# ######################### time taken to apply weights: 6.556510925292969e-05
# ######################### time taken to apply weights: 0.0002846717834472656
# ######################### time taken to apply weights: 4.6253204345703125e-05
# ######################### time taken to apply weights: 0.0029981136322021484
# ######################### time taken to apply weights: 0.001577615737915039
# ######################### time taken to apply weights: 0.0011920928955078125
# ######################### time taken to apply weights: 0.0013515949249267578
# ######################### time taken to apply weights: 0.0013086795806884766
# ######################### time taken to apply weights: 0.16762542724609375
# ######################### FULL time taken to apply weights: 0.1786210536956787
# ######################### time taken to apply weights: 0.0013420581817626953
# ######################### time taken to apply weights: 6.651878356933594e-05
# ######################### time taken to apply weights: 0.0002887248992919922
# ######################### time taken to apply weights: 3.790855407714844e-05
# ######################### time taken to apply weights: 0.0029823780059814453
# ######################### time taken to apply weights: 0.0015842914581298828
# ######################### time taken to apply weights: 0.0011811256408691406
# ######################### time taken to apply weights: 0.0013566017150878906
# ######################### time taken to apply weights: 0.001322031021118164
# ######################### time taken to apply weights: 0.164947509765625
# ######################### FULL time taken to apply weights: 0.17583060264587402
# ######################### time taken to apply weights: 0.0011491775512695312
# ######################### time taken to apply weights: 4.696846008300781e-05
# ######################### time taken to apply weights: 3.3855438232421875e-05
# ######################### time taken to apply weights: 2.5033950805664062e-05
# ######################### time taken to apply weights: 0.0035276412963867188
# ######################### time taken to apply weights: 0.0015687942504882812
# ######################### time taken to apply weights: 0.001173257827758789
# ######################### time taken to apply weights: 0.001374959945678711
# ######################### time taken to apply weights: 0.0013251304626464844
# ######################### time taken to apply weights: 0.16552972793579102
# ######################### FULL time taken to apply weights: 0.1765141487121582
# ######################### time taken to apply weights: 0.001153707504272461
# ######################### time taken to apply weights: 4.839897155761719e-05
# ######################### time taken to apply weights: 3.0994415283203125e-05
# ######################### time taken to apply weights: 2.6702880859375e-05
# ######################### time taken to apply weights: 0.0034058094024658203
# ######################### time taken to apply weights: 0.001573324203491211
# ######################### time taken to apply weights: 0.0012166500091552734
# ######################### time taken to apply weights: 0.0013463497161865234
# ######################### time taken to apply weights: 0.0013048648834228516
# ######################### time taken to apply weights: 0.1650998592376709
# ######################### FULL time taken to apply weights: 0.17586302757263184
# ######################### time taken to apply weights: 0.0011932849884033203
# ######################### time taken to apply weights: 4.696846008300781e-05
# ######################### time taken to apply weights: 0.0002918243408203125
# ######################### time taken to apply weights: 4.363059997558594e-05
# ######################### time taken to apply weights: 0.0033407211303710938
# ######################### time taken to apply weights: 0.0017123222351074219
# ######################### time taken to apply weights: 0.0012240409851074219
# ######################### time taken to apply weights: 0.0013706684112548828
# ######################### time taken to apply weights: 0.0013151168823242188
# ######################### time taken to apply weights: 0.1653745174407959
# ######################### FULL time taken to apply weights: 0.17678523063659668
# ######################### time taken to apply weights: 0.0011489391326904297
# ######################### time taken to apply weights: 5.364418029785156e-05
# ######################### time taken to apply weights: 3.647804260253906e-05
# ######################### time taken to apply weights: 3.0040740966796875e-05
# ######################### time taken to apply weights: 0.003520488739013672
# ######################### time taken to apply weights: 0.0015788078308105469
# ######################### time taken to apply weights: 0.0011887550354003906
# ######################### time taken to apply weights: 0.001409292221069336
# ######################### time taken to apply weights: 0.0013077259063720703
# ######################### time taken to apply weights: 0.16757678985595703
# ######################### FULL time taken to apply weights: 0.17864465713500977
# ######################### time taken to apply weights: 0.0011887550354003906
# ######################### time taken to apply weights: 5.698204040527344e-05
# ######################### time taken to apply weights: 0.0002903938293457031
# ######################### time taken to apply weights: 4.38690185546875e-05
# ######################### time taken to apply weights: 0.003061056137084961
# ######################### time taken to apply weights: 0.0015530586242675781
# ######################### time taken to apply weights: 0.0012536048889160156
# ######################### time taken to apply weights: 0.0013544559478759766
# ######################### time taken to apply weights: 0.001298666000366211
# ######################### time taken to apply weights: 0.16564178466796875
# ######################### FULL time taken to apply weights: 0.1765308380126953
# ######################### time taken to apply weights: 0.0011696815490722656
# ######################### time taken to apply weights: 4.935264587402344e-05
# ######################### time taken to apply weights: 3.0279159545898438e-05
# ######################### time taken to apply weights: 2.5033950805664062e-05
# ######################### time taken to apply weights: 0.0034389495849609375
# ######################### time taken to apply weights: 0.0016112327575683594
# ######################### time taken to apply weights: 0.0012278556823730469
# ######################### time taken to apply weights: 0.001346588134765625
# ######################### time taken to apply weights: 0.0013065338134765625
# ######################### time taken to apply weights: 0.16577959060668945
# ######################### FULL time taken to apply weights: 0.17673420906066895
# ######################### time taken to apply weights: 0.0011429786682128906
# ######################### time taken to apply weights: 5.340576171875e-05
# ######################### time taken to apply weights: 3.9577484130859375e-05
# ######################### time taken to apply weights: 3.123283386230469e-05
# ######################### time taken to apply weights: 0.0035393238067626953
# ######################### time taken to apply weights: 0.0016045570373535156
# ######################### time taken to apply weights: 0.0012083053588867188
# ######################### time taken to apply weights: 0.0013775825500488281
# ######################### time taken to apply weights: 0.0013186931610107422
# ######################### time taken to apply weights: 0.16499900817871094
# ######################### FULL time taken to apply weights: 0.1761023998260498
# ######################### time taken to apply weights: 0.0011501312255859375
# ######################### time taken to apply weights: 4.6253204345703125e-05
# ######################### time taken to apply weights: 0.0002715587615966797
# ######################### time taken to apply weights: 4.2438507080078125e-05
# ######################### time taken to apply weights: 0.0033512115478515625
# ######################### time taken to apply weights: 0.0015583038330078125
# ######################### time taken to apply weights: 0.0010709762573242188
# ######################### time taken to apply weights: 0.0012505054473876953
# ######################### time taken to apply weights: 0.001050710678100586
# ######################### time taken to apply weights: 0.16737794876098633
# ######################### FULL time taken to apply weights: 0.17788314819335938
# ######################### time taken to apply weights: 0.001142263412475586
# ######################### time taken to apply weights: 4.982948303222656e-05
# ######################### time taken to apply weights: 3.9577484130859375e-05
# ######################### time taken to apply weights: 2.956390380859375e-05
# ######################### time taken to apply weights: 0.0034284591674804688
# ######################### time taken to apply weights: 0.0015904903411865234
# ######################### time taken to apply weights: 0.0012066364288330078
# ######################### time taken to apply weights: 0.0013608932495117188
# ######################### time taken to apply weights: 0.0013086795806884766
# ######################### time taken to apply weights: 0.1671898365020752
# ######################### FULL time taken to apply weights: 0.17813563346862793
# ######################### time taken to apply weights: 0.0013513565063476562
# ######################### time taken to apply weights: 6.127357482910156e-05
# ######################### time taken to apply weights: 0.0003116130828857422
# ######################### time taken to apply weights: 4.0531158447265625e-05
# ######################### time taken to apply weights: 0.002982616424560547
# ######################### time taken to apply weights: 0.0015676021575927734
# ######################### time taken to apply weights: 0.0012006759643554688
# ######################### time taken to apply weights: 0.0013654232025146484
# ######################### time taken to apply weights: 0.0012290477752685547
# ######################### time taken to apply weights: 0.16806674003601074
# ######################### FULL time taken to apply weights: 0.17878055572509766
# ######################### time taken to apply weights: 0.001203775405883789
# ######################### time taken to apply weights: 6.29425048828125e-05
# ######################### time taken to apply weights: 0.0002942085266113281
# ######################### time taken to apply weights: 4.410743713378906e-05
# ######################### time taken to apply weights: 0.003008604049682617
# ######################### time taken to apply weights: 0.0015575885772705078
# ######################### time taken to apply weights: 0.0011789798736572266
# ######################### time taken to apply weights: 0.001355886459350586
# ######################### time taken to apply weights: 0.001310110092163086
# ######################### time taken to apply weights: 0.16628265380859375
# ######################### FULL time taken to apply weights: 0.17697620391845703
# ######################### time taken to apply weights: 0.0013179779052734375
# ######################### time taken to apply weights: 7.081031799316406e-05
# ######################### time taken to apply weights: 0.0002703666687011719
# ######################### time taken to apply weights: 4.506111145019531e-05
# ######################### time taken to apply weights: 0.0030586719512939453
# ######################### time taken to apply weights: 0.00156402587890625
# ######################### time taken to apply weights: 0.0011713504791259766
# ######################### time taken to apply weights: 0.0013496875762939453
# ######################### time taken to apply weights: 0.0012972354888916016
# ######################### time taken to apply weights: 0.16708016395568848
# ######################### FULL time taken to apply weights: 0.1778736114501953
# ######################### time taken to apply weights: 0.0014431476593017578
# ######################### time taken to apply weights: 6.198883056640625e-05
# ######################### time taken to apply weights: 0.0002739429473876953
# ######################### time taken to apply weights: 4.267692565917969e-05
# ######################### time taken to apply weights: 0.0030045509338378906
# ######################### time taken to apply weights: 0.0015635490417480469
# ######################### time taken to apply weights: 0.0011985301971435547
# ######################### time taken to apply weights: 0.001371622085571289
# ######################### time taken to apply weights: 0.0013165473937988281
# ######################### time taken to apply weights: 0.16586947441101074
# ######################### FULL time taken to apply weights: 0.17693471908569336
# ######################### time taken to apply weights: 0.0013742446899414062
# ######################### time taken to apply weights: 6.031990051269531e-05
# ######################### time taken to apply weights: 9.942054748535156e-05
# ######################### time taken to apply weights: 3.838539123535156e-05
# ######################### time taken to apply weights: 0.002982616424560547
# ######################### time taken to apply weights: 0.0015559196472167969
# ######################### time taken to apply weights: 0.0011813640594482422
# ######################### time taken to apply weights: 0.0013725757598876953
# ######################### time taken to apply weights: 0.0010669231414794922
# ######################### time taken to apply weights: 0.16744303703308105
# ######################### FULL time taken to apply weights: 0.178147554397583
# ######################### time taken to apply weights: 0.0013742446899414062
# ######################### time taken to apply weights: 6.246566772460938e-05
# ######################### time taken to apply weights: 0.0002536773681640625
# ######################### time taken to apply weights: 3.886222839355469e-05
# ######################### time taken to apply weights: 0.002977132797241211
# ######################### time taken to apply weights: 0.0015628337860107422
# ######################### time taken to apply weights: 0.0011794567108154297
# ######################### time taken to apply weights: 0.0013720989227294922
# ######################### time taken to apply weights: 0.0013303756713867188
# ######################### time taken to apply weights: 0.16711688041687012
# ######################### FULL time taken to apply weights: 0.17804646492004395
# ######################### time taken to apply weights: 0.001367330551147461
# ######################### time taken to apply weights: 6.937980651855469e-05
# ######################### time taken to apply weights: 0.00015807151794433594
# ######################### time taken to apply weights: 4.220008850097656e-05
# ######################### time taken to apply weights: 0.0029256343841552734
# ######################### time taken to apply weights: 0.0015597343444824219
# ######################### time taken to apply weights: 0.0011816024780273438
# ######################### time taken to apply weights: 0.0013573169708251953
# ######################### time taken to apply weights: 0.0013179779052734375
# ######################### time taken to apply weights: 0.16682910919189453
# ######################### FULL time taken to apply weights: 0.17778444290161133
# ######################### time taken to apply weights: 0.0013995170593261719
# ######################### time taken to apply weights: 6.127357482910156e-05
# ######################### time taken to apply weights: 0.0002944469451904297
# ######################### time taken to apply weights: 4.267692565917969e-05
# ######################### time taken to apply weights: 0.0030007362365722656
# ######################### time taken to apply weights: 0.0015838146209716797
# ######################### time taken to apply weights: 0.0011806488037109375
# ######################### time taken to apply weights: 0.0013740062713623047
# ######################### time taken to apply weights: 0.00133514404296875
# ######################### time taken to apply weights: 0.16536641120910645
# ######################### FULL time taken to apply weights: 0.17633843421936035
# ######################### time taken to apply weights: 0.0011823177337646484
# ######################### time taken to apply weights: 5.030632019042969e-05
# ######################### time taken to apply weights: 3.457069396972656e-05
# ######################### time taken to apply weights: 2.7894973754882812e-05
# ######################### time taken to apply weights: 0.003559112548828125
# ######################### time taken to apply weights: 0.00160980224609375
# ######################### time taken to apply weights: 0.0012145042419433594
# ######################### time taken to apply weights: 0.0014121532440185547
# ######################### time taken to apply weights: 0.0013113021850585938
# ######################### time taken to apply weights: 0.16811561584472656
# ######################### FULL time taken to apply weights: 0.17929673194885254
# ######################### time taken to apply weights: 0.001222372055053711
# ######################### time taken to apply weights: 6.532669067382812e-05
# ######################### time taken to apply weights: 0.0002734661102294922
# ######################### time taken to apply weights: 4.363059997558594e-05
# ######################### time taken to apply weights: 0.0030260086059570312
# ######################### time taken to apply weights: 0.0015561580657958984
# ######################### time taken to apply weights: 0.0011744499206542969
# ######################### time taken to apply weights: 0.0013499259948730469
# ######################### time taken to apply weights: 0.0013132095336914062
# ######################### time taken to apply weights: 0.16803407669067383
# ######################### FULL time taken to apply weights: 0.1787571907043457
# ######################### time taken to apply weights: 0.0015616416931152344
# ######################### time taken to apply weights: 6.937980651855469e-05
# ######################### time taken to apply weights: 0.00027561187744140625
# ######################### time taken to apply weights: 4.267692565917969e-05
# ######################### time taken to apply weights: 0.0030210018157958984
# ######################### time taken to apply weights: 0.0015909671783447266
# ######################### time taken to apply weights: 0.0011832714080810547
# ######################### time taken to apply weights: 0.001354217529296875
# ######################### time taken to apply weights: 0.0013239383697509766
# ######################### time taken to apply weights: 0.16738247871398926
# ######################### FULL time taken to apply weights: 0.17852473258972168
# ######################### time taken to apply weights: 0.0013637542724609375
# ######################### time taken to apply weights: 7.462501525878906e-05
# ######################### time taken to apply weights: 0.00029778480529785156
# ######################### time taken to apply weights: 4.1484832763671875e-05
# ######################### time taken to apply weights: 0.0029141902923583984
# ######################### time taken to apply weights: 0.0015726089477539062
# ######################### time taken to apply weights: 0.0011830329895019531
# ######################### time taken to apply weights: 0.0013802051544189453
# ######################### time taken to apply weights: 0.0013310909271240234
# ######################### time taken to apply weights: 0.16678690910339355
# ######################### FULL time taken to apply weights: 0.17787671089172363
# ######################### time taken to apply weights: 0.001352548599243164
# ######################### time taken to apply weights: 6.103515625e-05
# ######################### time taken to apply weights: 0.0002713203430175781
# ######################### time taken to apply weights: 4.4345855712890625e-05
# ######################### time taken to apply weights: 0.0030684471130371094
# ...
# ######################### time taken to apply weights: 0.001584768295288086
# ######################### time taken to apply weights: 0.001195669174194336
# ######################### time taken to apply weights: 0.001375436782836914
# ######################### time taken to apply weights: 0.0013203620910644531
# ######################### time taken to apply weights: 0.16878509521484375
# ######################### FULL time taken to apply weights: 0.17933416366577148
# ######################### time taken to apply weights: 0.0011723041534423828
# ######################### time taken to apply weights: 5.7220458984375e-05
# ######################### time taken to apply weights: 0.0002033710479736328
# ######################### time taken to apply weights: 4.1961669921875e-05
# ######################### time taken to apply weights: 0.002913236618041992
# ######################### time taken to apply weights: 0.0015902519226074219
# ######################### time taken to apply weights: 0.0012106895446777344
# ######################### time taken to apply weights: 0.001375436782836914
# ######################### time taken to apply weights: 0.0013248920440673828
# ######################### time taken to apply weights: 0.16852951049804688
# ######################### FULL time taken to apply weights: 0.17907953262329102
# ######################### time taken to apply weights: 0.001172780990600586
# ######################### time taken to apply weights: 5.4836273193359375e-05
# ######################### time taken to apply weights: 0.0002052783966064453
# ######################### time taken to apply weights: 4.792213439941406e-05
# ######################### time taken to apply weights: 0.002927541732788086
# ######################### time taken to apply weights: 0.0015976428985595703
# ######################### time taken to apply weights: 0.0011894702911376953
# ######################### time taken to apply weights: 0.0013744831085205078
# ######################### time taken to apply weights: 0.001325368881225586
# ######################### time taken to apply weights: 0.16777992248535156
# ######################### FULL time taken to apply weights: 0.17832732200622559
# ######################### time taken to apply weights: 0.001138925552368164
# ######################### time taken to apply weights: 4.4345855712890625e-05
# ######################### time taken to apply weights: 0.00019478797912597656
# ######################### time taken to apply weights: 4.220008850097656e-05
# ######################### time taken to apply weights: 0.002930164337158203
# ######################### time taken to apply weights: 0.0015947818756103516
# ######################### time taken to apply weights: 0.0011925697326660156
# ######################### time taken to apply weights: 0.0013709068298339844
# ######################### time taken to apply weights: 0.0013446807861328125
# ######################### time taken to apply weights: 0.16698884963989258
# ######################### FULL time taken to apply weights: 0.17749357223510742
# ######################### time taken to apply weights: 0.0011930465698242188
# ######################### time taken to apply weights: 5.173683166503906e-05
# ######################### time taken to apply weights: 0.00020051002502441406
# ######################### time taken to apply weights: 4.1961669921875e-05
# ######################### time taken to apply weights: 0.0029146671295166016
# ######################### time taken to apply weights: 0.0016088485717773438
# ######################### time taken to apply weights: 0.0011894702911376953
# ######################### time taken to apply weights: 0.0013740062713623047
# ######################### time taken to apply weights: 0.001321554183959961
# ######################### time taken to apply weights: 0.16892790794372559
# ######################### FULL time taken to apply weights: 0.179490327835083
# ######################### time taken to apply weights: 0.0011560916900634766
# ######################### time taken to apply weights: 5.316734313964844e-05
# ######################### time taken to apply weights: 0.00019216537475585938
# ######################### time taken to apply weights: 3.981590270996094e-05
# ######################### time taken to apply weights: 0.0029191970825195312
# ######################### time taken to apply weights: 0.0015959739685058594
# ######################### time taken to apply weights: 0.0011975765228271484
# ######################### time taken to apply weights: 0.0013697147369384766
# ######################### time taken to apply weights: 0.001337289810180664
# ######################### time taken to apply weights: 0.16947126388549805
# ######################### FULL time taken to apply weights: 0.17988300323486328
# ######################### time taken to apply weights: 0.0011725425720214844
# ######################### time taken to apply weights: 5.078315734863281e-05
# ######################### time taken to apply weights: 0.00019478797912597656
# ######################### time taken to apply weights: 4.0531158447265625e-05
# ######################### time taken to apply weights: 0.002929210662841797
# ######################### time taken to apply weights: 0.0015978813171386719
# ######################### time taken to apply weights: 0.0012400150299072266
# ######################### time taken to apply weights: 0.001401662826538086
# ######################### time taken to apply weights: 0.0010683536529541016
# ######################### time taken to apply weights: 0.16906046867370605
# ######################### FULL time taken to apply weights: 0.17929720878601074
# ######################### time taken to apply weights: 0.0011661052703857422
# ######################### time taken to apply weights: 5.245208740234375e-05
# ######################### time taken to apply weights: 0.0001938343048095703
# ######################### time taken to apply weights: 4.172325134277344e-05
# ######################### time taken to apply weights: 0.0029354095458984375
# ######################### time taken to apply weights: 0.0015990734100341797
# ######################### time taken to apply weights: 0.0011861324310302734
# ######################### time taken to apply weights: 0.0013647079467773438
# ######################### time taken to apply weights: 0.0013282299041748047
# ######################### time taken to apply weights: 0.1686549186706543
# ######################### FULL time taken to apply weights: 0.17917537689208984
# ######################### time taken to apply weights: 0.001178741455078125
# ######################### time taken to apply weights: 5.316734313964844e-05
# ######################### time taken to apply weights: 0.00020360946655273438
# ######################### time taken to apply weights: 4.315376281738281e-05
# ######################### time taken to apply weights: 0.0029299259185791016
# ######################### time taken to apply weights: 0.0015931129455566406
# ######################### time taken to apply weights: 0.0012054443359375
# ######################### time taken to apply weights: 0.0013432502746582031
# ######################### time taken to apply weights: 0.0013251304626464844
# ######################### time taken to apply weights: 0.16851067543029785
# ######################### FULL time taken to apply weights: 0.1790447235107422
# ######################### time taken to apply weights: 0.0011744499206542969
# ######################### time taken to apply weights: 5.269050598144531e-05
# ######################### time taken to apply weights: 0.00020074844360351562
# ######################### time taken to apply weights: 4.172325134277344e-05
# ######################### time taken to apply weights: 0.0029306411743164062
# ######################### time taken to apply weights: 0.0015978813171386719
# ######################### time taken to apply weights: 0.0012102127075195312
# ######################### time taken to apply weights: 0.0013775825500488281
# ######################### time taken to apply weights: 0.001325845718383789
# ######################### time taken to apply weights: 0.1668391227722168
# ######################### FULL time taken to apply weights: 0.17740750312805176
# ######################### time taken to apply weights: 0.0011446475982666016
# ######################### time taken to apply weights: 5.435943603515625e-05
# ######################### time taken to apply weights: 0.00019884109497070312
# ######################### time taken to apply weights: 4.172325134277344e-05
# ######################### time taken to apply weights: 0.0029201507568359375
# ######################### time taken to apply weights: 0.0015926361083984375
# ######################### time taken to apply weights: 0.0011928081512451172
# ######################### time taken to apply weights: 0.0013842582702636719
# ######################### time taken to apply weights: 0.0013206005096435547
# ######################### time taken to apply weights: 0.16980648040771484
# ######################### FULL time taken to apply weights: 0.18031024932861328
# ######################### time taken to apply weights: 0.0011820793151855469
# ######################### time taken to apply weights: 5.91278076171875e-05
# ######################### time taken to apply weights: 0.0002110004425048828
# ######################### time taken to apply weights: 4.458427429199219e-05
# ######################### time taken to apply weights: 0.0029630661010742188
# ######################### time taken to apply weights: 0.0015964508056640625
# ######################### time taken to apply weights: 0.0010890960693359375
# ######################### time taken to apply weights: 0.0012738704681396484
# ######################### time taken to apply weights: 0.0010657310485839844
# ######################### time taken to apply weights: 0.1677703857421875
# ######################### FULL time taken to apply weights: 0.1777935028076172
# ######################### time taken to apply weights: 0.0011649131774902344
# ######################### time taken to apply weights: 4.649162292480469e-05
# ######################### time taken to apply weights: 0.00019931793212890625
# ######################### time taken to apply weights: 3.5762786865234375e-05
# ######################### time taken to apply weights: 0.002968311309814453
# ######################### time taken to apply weights: 0.0015914440155029297
# ######################### time taken to apply weights: 0.0011818408966064453
# ######################### time taken to apply weights: 0.0013620853424072266
# ######################### time taken to apply weights: 0.0013217926025390625
# ######################### time taken to apply weights: 0.16836285591125488
# ######################### FULL time taken to apply weights: 0.17888522148132324
# ######################### time taken to apply weights: 0.0011680126190185547
# ######################### time taken to apply weights: 5.078315734863281e-05
# ######################### time taken to apply weights: 0.00020241737365722656
# ######################### time taken to apply weights: 3.600120544433594e-05
# ######################### time taken to apply weights: 0.0029125213623046875
# ######################### time taken to apply weights: 0.0015718936920166016
# ######################### time taken to apply weights: 0.0011816024780273438
# ######################### time taken to apply weights: 0.0013644695281982422
# ######################### time taken to apply weights: 0.0013191699981689453
# ######################### time taken to apply weights: 0.16619396209716797
# ######################### FULL time taken to apply weights: 0.17665791511535645
# time taken to multiply coil sensitivity maps for average 0/50: 0.21300959587097168
# time taken to multiply coil sensitivity maps for average 1/50: 0.13677287101745605
# time taken to multiply coil sensitivity maps for average 2/50: 0.14056992530822754
# time taken to multiply coil sensitivity maps for average 3/50: 0.13895273208618164
# time taken to multiply coil sensitivity maps for average 4/50: 0.13673901557922363
# time taken to multiply coil sensitivity maps for average 5/50: 0.13744425773620605
# time taken to multiply coil sensitivity maps for average 6/50: 0.14031028747558594
# time taken to multiply coil sensitivity maps for average 7/50: 0.1382286548614502
# time taken to multiply coil sensitivity maps for average 8/50: 0.13594985008239746
# time taken to multiply coil sensitivity maps for average 9/50: 0.13772106170654297
# time taken to multiply coil sensitivity maps for average 10/50: 0.1425480842590332
# time taken to multiply coil sensitivity maps for average 11/50: 0.13744878768920898
# time taken to multiply coil sensitivity maps for average 12/50: 0.13667702674865723
# time taken to multiply coil sensitivity maps for average 13/50: 0.13833880424499512
# time taken to multiply coil sensitivity maps for average 14/50: 0.14136481285095215
# time taken to multiply coil sensitivity maps for average 15/50: 0.1367173194885254
# time taken to multiply coil sensitivity maps for average 16/50: 0.1364278793334961
# time taken to multiply coil sensitivity maps for average 17/50: 0.13855981826782227
# time taken to multiply coil sensitivity maps for average 18/50: 0.13974857330322266
# time taken to multiply coil sensitivity maps for average 19/50: 0.1360483169555664
# time taken to multiply coil sensitivity maps for average 20/50: 0.13732004165649414
# time taken to multiply coil sensitivity maps for average 21/50: 0.13871073722839355
# time taken to multiply coil sensitivity maps for average 22/50: 0.13953566551208496
# time taken to multiply coil sensitivity maps for average 23/50: 0.1350862979888916
# time taken to multiply coil sensitivity maps for average 24/50: 0.13819479942321777
# time taken to multiply coil sensitivity maps for average 25/50: 0.13843536376953125
# time taken to multiply coil sensitivity maps for average 26/50: 0.13878846168518066
# time taken to multiply coil sensitivity maps for average 27/50: 0.13529753684997559
# time taken to multiply coil sensitivity maps for average 28/50: 0.13920068740844727
# time taken to multiply coil sensitivity maps for average 29/50: 0.13899779319763184
# time taken to multiply coil sensitivity maps for average 30/50: 0.13725042343139648
# time taken to multiply coil sensitivity maps for average 31/50: 0.13669705390930176
# time taken to multiply coil sensitivity maps for average 32/50: 0.14008069038391113
# time taken to multiply coil sensitivity maps for average 33/50: 0.1391761302947998
# time taken to multiply coil sensitivity maps for average 34/50: 0.1363363265991211
# time taken to multiply coil sensitivity maps for average 35/50: 0.13622832298278809
# time taken to multiply coil sensitivity maps for average 36/50: 0.14263558387756348
# time taken to multiply coil sensitivity maps for average 37/50: 0.1391453742980957
# time taken to multiply coil sensitivity maps for average 38/50: 0.13580656051635742
# time taken to multiply coil sensitivity maps for average 39/50: 0.13689541816711426
# time taken to multiply coil sensitivity maps for average 40/50: 0.1405799388885498
# time taken to multiply coil sensitivity maps for average 41/50: 0.1375885009765625
# time taken to multiply coil sensitivity maps for average 42/50: 0.13881373405456543
# time taken to multiply coil sensitivity maps for average 43/50: 0.13732576370239258
# time taken to multiply coil sensitivity maps for average 44/50: 0.1405336856842041
# time taken to multiply coil sensitivity maps for average 45/50: 0.13691997528076172
# time taken to multiply coil sensitivity maps for average 46/50: 0.13620305061340332
# time taken to multiply coil sensitivity maps for average 47/50: 0.13849234580993652
# time taken to multiply coil sensitivity maps for average 48/50: 0.1403188705444336
# time taken to multiply coil sensitivity maps for average 49/50: 0.136275053024292
# time taken to compute_averages function: 0.11011528968811035
# time taken to compute trace, ADC, b1500: 0.6098015308380127
# Size of B50x image (as an example):
# (30, 100, 100)
# Size of ADC map (as an example):
# (30, 100, 100)
# CPU times: user 5min 59s, sys: 2min 26s, total: 8min 26s
# Wall time: 5min 54s

# %% [markdown]
# ### Plotting the reconstructed DWI images, which contained by the same field names in the h5 file

# %%
def display_dwi_slice(dwi_recons, slice_num):
    _, ax = plt.subplots(2, 5, figsize=(12,5))
    
    for idx, k in enumerate(['b50x', 'b50y', 'b50z', 'trace_b50', 'adc_map']):
        if type(dwi_recons[k]) == torch.Tensor:
            ax[0][idx].imshow(dwi_recons[k][slice_num, :, :].cpu().numpy(), cmap='gray')
        else:
            ax[0][idx].imshow(dwi_recons[k][slice_num, :, :], cmap='gray')
        ax[0][idx].title.set_text(k)
        ax[0][idx].axis("off")
    
    for idx, k in enumerate(['b1000x', 'b1000y', 'b1000z', 'trace_b1000', 'b1500']):
        if type(dwi_recons[k]) == torch.Tensor:
            ax[1][idx].imshow(dwi_recons[k][slice_num, :, :].cpu().numpy(), cmap='gray')
        else:
            ax[1][idx].imshow(dwi_recons[k][slice_num, :, :], cmap='gray')
        ax[1][idx].title.set_text(k)
        ax[1][idx].axis("off")

        
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    plt.show()

# display_dwi_slice(img_dict_dwi, 10)

# %% [markdown]
# ### torch optimized Grappa

# %%
from fastmri_prostate.reconstruction.dwi.prostate_dwi_recon_torch import dwi_reconstruction
import torch

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

ismrmrd_header = {k: torch.tensor(v, device=device) for k, v in ismrmrd_header.items()}
kspace = torch.tensor(kspace, device=device)
calibration_data = torch.tensor(calibration_data, device=device)
coil_sens_maps = torch.tensor(coil_sens_maps, device=device)

# %%
img_dict_dwi = dwi_reconstruction(kspace, calibration_data, coil_sens_maps, ismrmrd_header)
print("Size of B50x image (as an example):")
print(img_dict_dwi['b50x'].shape)
print("Size of ADC map (as an example):")
print(img_dict_dwi['adc_map'].shape)
# Out:
# time taken to compute weights for slice 0: 0.03773927688598633
# time taken to compute weights for slice 1: 0.035356760025024414
# time taken to compute weights for slice 2: 0.039232492446899414
# time taken to compute weights for slice 3: 0.18520164489746094
# time taken to compute weights for slice 4: 0.032581329345703125
# time taken to compute weights for slice 5: 0.03165388107299805
# time taken to compute weights for slice 6: 0.03780364990234375
# time taken to compute weights for slice 7: 0.18265581130981445
# time taken to compute weights for slice 8: 0.03272271156311035
# time taken to compute weights for slice 9: 0.0314788818359375
# time taken to compute weights for slice 10: 0.03771710395812988
# time taken to compute weights for slice 11: 0.18290352821350098
# time taken to compute weights for slice 12: 0.03295612335205078
# time taken to compute weights for slice 13: 0.03164839744567871
# time taken to compute weights for slice 14: 0.03729963302612305
# time taken to compute weights for slice 15: 0.18505191802978516
# time taken to compute weights for slice 16: 0.032074928283691406
# time taken to compute weights for slice 17: 0.03149294853210449
# time taken to compute weights for slice 18: 0.03786802291870117
# time taken to compute weights for slice 19: 0.1844327449798584
# time taken to compute weights for slice 20: 0.03326749801635742
# time taken to compute weights for slice 21: 0.03154754638671875
# time taken to compute weights for slice 22: 0.03784346580505371
# time taken to compute weights for slice 23: 0.1839303970336914
# time taken to compute weights for slice 24: 0.03220558166503906
# time taken to compute weights for slice 25: 0.03162360191345215
# time taken to compute weights for slice 26: 0.03730607032775879
# time taken to compute weights for slice 27: 0.1833207607269287
# time taken to compute weights for slice 28: 0.03179931640625
# time taken to compute weights for slice 29: 0.03178119659423828
# time taken to apply weights for average 0/50: 1.7394073009490967
# time taken to apply weights for average 1/50: 1.7371490001678467
# time taken to apply weights for average 2/50: 1.7374193668365479
# time taken to apply weights for average 3/50: 1.7374539375305176
# time taken to apply weights for average 4/50: 1.7341680526733398
# time taken to apply weights for average 5/50: 1.7370712757110596
# time taken to apply weights for average 6/50: 1.734565019607544
# time taken to apply weights for average 7/50: 1.7447922229766846
# time taken to apply weights for average 8/50: 1.74151611328125
# time taken to apply weights for average 9/50: 1.737480878829956
# time taken to apply weights for average 10/50: 1.7374286651611328
# time taken to apply weights for average 11/50: 1.7314443588256836
# time taken to apply weights for average 12/50: 1.7364039421081543
# time taken to apply weights for average 13/50: 1.764620065689087
# time taken to apply weights for average 14/50: 1.7345232963562012
# time taken to apply weights for average 15/50: 1.728175401687622
# time taken to apply weights for average 16/50: 1.7334375381469727
# time taken to apply weights for average 17/50: 1.7302093505859375
# time taken to apply weights for average 18/50: 1.7415199279785156
# time taken to apply weights for average 19/50: 1.7425286769866943
# time taken to apply weights for average 20/50: 1.7385985851287842
# time taken to apply weights for average 21/50: 1.7499289512634277
# time taken to apply weights for average 22/50: 1.7434875965118408
# time taken to apply weights for average 23/50: 1.9087674617767334
# time taken to apply weights for average 24/50: 1.7324721813201904
# time taken to apply weights for average 25/50: 1.7370431423187256
# time taken to apply weights for average 26/50: 1.7330303192138672
# time taken to apply weights for average 27/50: 1.73018217086792
# time taken to apply weights for average 28/50: 1.7307813167572021
# time taken to apply weights for average 29/50: 1.7276864051818848
# time taken to apply weights for average 30/50: 1.7293663024902344
# time taken to apply weights for average 31/50: 1.730424404144287
# time taken to apply weights for average 32/50: 1.729719877243042
# time taken to apply weights for average 33/50: 1.7318806648254395
# time taken to apply weights for average 34/50: 1.747504472732544
# time taken to apply weights for average 35/50: 1.7366857528686523
# time taken to apply weights for average 36/50: 1.7346911430358887
# time taken to apply weights for average 37/50: 1.7266218662261963
# time taken to apply weights for average 38/50: 1.7361602783203125
# time taken to apply weights for average 39/50: 1.7308647632598877
# time taken to apply weights for average 40/50: 1.7353777885437012
# time taken to apply weights for average 41/50: 1.7354767322540283
# time taken to apply weights for average 42/50: 1.7443103790283203
# time taken to apply weights for average 43/50: 1.742276906967163
# time taken to apply weights for average 44/50: 1.7513453960418701
# time taken to apply weights for average 45/50: 1.743873119354248
# time taken to apply weights for average 46/50: 1.7537200450897217
# time taken to apply weights for average 47/50: 1.7502644062042236
# time taken to apply weights for average 48/50: 1.7452123165130615
# time taken to apply weights for average 49/50: 1.7454018592834473
# time taken to multiply coil se for average 0/50: 0.0007801055908203125
# time taken to multiply coil se for average 1/50: 6.937980651855469e-05
# time taken to multiply coil se for average 2/50: 5.626678466796875e-05
# time taken to multiply coil se for average 3/50: 5.555152893066406e-05
# time taken to multiply coil se for average 4/50: 6.0558319091796875e-05
# time taken to multiply coil se for average 5/50: 5.2928924560546875e-05
# time taken to multiply coil se for average 6/50: 5.269050598144531e-05
# time taken to multiply coil se for average 7/50: 5.1975250244140625e-05
# time taken to multiply coil se for average 8/50: 5.14984130859375e-05
# time taken to multiply coil se for average 9/50: 5.14984130859375e-05
# time taken to multiply coil se for average 10/50: 5.1021575927734375e-05
# time taken to multiply coil se for average 11/50: 5.269050598144531e-05
# time taken to multiply coil se for average 12/50: 0.0002009868621826172
# time taken to multiply coil se for average 13/50: 6.008148193359375e-05
# time taken to multiply coil se for average 14/50: 4.76837158203125e-05
# time taken to multiply coil se for average 15/50: 4.553794860839844e-05
# time taken to multiply coil se for average 16/50: 4.57763671875e-05
# time taken to multiply coil se for average 17/50: 4.482269287109375e-05
# time taken to multiply coil se for average 18/50: 4.7206878662109375e-05
# time taken to multiply coil se for average 19/50: 4.458427429199219e-05
# time taken to multiply coil se for average 20/50: 4.553794860839844e-05
# time taken to multiply coil se for average 21/50: 4.482269287109375e-05
# time taken to multiply coil se for average 22/50: 4.410743713378906e-05
# time taken to multiply coil se for average 23/50: 4.4345855712890625e-05
# time taken to multiply coil se for average 24/50: 4.410743713378906e-05
# time taken to multiply coil se for average 25/50: 4.363059997558594e-05
# time taken to multiply coil se for average 26/50: 4.220008850097656e-05
# time taken to multiply coil se for average 27/50: 4.267692565917969e-05
# time taken to multiply coil se for average 28/50: 4.2438507080078125e-05
# time taken to multiply coil se for average 29/50: 4.3392181396484375e-05
# time taken to multiply coil se for average 30/50: 4.315376281738281e-05
# time taken to multiply coil se for average 31/50: 4.315376281738281e-05
# time taken to multiply coil se for average 32/50: 4.220008850097656e-05
# time taken to multiply coil se for average 33/50: 4.2438507080078125e-05
# time taken to multiply coil se for average 34/50: 4.291534423828125e-05
# time taken to multiply coil se for average 35/50: 4.220008850097656e-05
# time taken to multiply coil se for average 36/50: 4.315376281738281e-05
# time taken to multiply coil se for average 37/50: 4.744529724121094e-05
# time taken to multiply coil se for average 38/50: 4.410743713378906e-05
# time taken to multiply coil se for average 39/50: 4.291534423828125e-05
# time taken to multiply coil se for average 40/50: 4.3392181396484375e-05
# time taken to multiply coil se for average 41/50: 4.172325134277344e-05
# time taken to multiply coil se for average 42/50: 3.933906555175781e-05
# time taken to multiply coil se for average 43/50: 3.933906555175781e-05
# time taken to multiply coil se for average 44/50: 3.886222839355469e-05
# time taken to multiply coil se for average 45/50: 3.8623809814453125e-05
# time taken to multiply coil se for average 46/50: 3.8623809814453125e-05
# time taken to multiply coil se for average 47/50: 3.910064697265625e-05
# time taken to multiply coil se for average 48/50: 3.838539123535156e-05
# time taken to multiply coil se for average 49/50: 3.910064697265625e-05
# time taken to compute_averages function: 0.00024628639221191406
# changed
# time taken to compute trace, ADC, b1500: 0.3411726951599121
# Size of B50x image (as an example):
# torch.Size([30, 100, 100])
# Size of ADC map (as an example):
# torch.Size([30, 100, 100])

# %%
img_dict_dwi['b1500'].shape, img_dict_dwi['adc_map'].shape
# Out:
# (torch.Size([30, 100, 100]), torch.Size([30, 100, 100]))

# %%
display_dwi_slice(img_dict_dwi, 10)

# %%
# !nvidia-smi
